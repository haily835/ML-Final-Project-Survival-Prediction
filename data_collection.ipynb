# %%
import pandas as pd
import os

if not os.path.exists('./data'):
    os.makedirs('./data')

prefix_path = './data/brca_metabric'

# %%
clinical_sample_df = pd.read_csv(f'{prefix_path}/data_clinical_sample.txt', delimiter='\t', skiprows=4)
clinical_sample_df
# Out:
#      PATIENT_ID  SAMPLE_ID    CANCER_TYPE  \
# 0       MB-0000    MB-0000  Breast Cancer
# 1       MB-0002    MB-0002  Breast Cancer
# 2       MB-0005    MB-0005  Breast Cancer
# 3       MB-0006    MB-0006  Breast Cancer
# 4       MB-0008    MB-0008  Breast Cancer
# ...         ...        ...            ...
# 2504  MTS-T2428  MTS-T2428  Breast Cancer
# 2505  MTS-T2429  MTS-T2429  Breast Cancer
# 2506  MTS-T2430  MTS-T2430  Breast Cancer
# 2507  MTS-T2431  MTS-T2431  Breast Cancer
# 2508  MTS-T2432  MTS-T2432  Breast Cancer
#
#                            CANCER_TYPE_DETAILED ER_STATUS HER2_STATUS  GRADE  \
# 0              Breast Invasive Ductal Carcinoma  Positive    Negative    3.0
# 1              Breast Invasive Ductal Carcinoma  Positive    Negative    3.0
# 2              Breast Invasive Ductal Carcinoma  Positive    Negative    2.0
# 3     Breast Mixed Ductal and Lobular Carcinoma  Positive    Negative    2.0
# ...

# %%
data_clinical_patient = pd.read_csv(f'.{prefix_path}/data_clinical_patient.txt', delimiter='\t')
data_clinical_patient
# Out:
#      PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY  \
# 0       MB-0000                           10.0  6.044         NaN
# 1       MB-0002                            0.0  4.020        High
# 2       MB-0005                            1.0  4.030        High
# 3       MB-0006                            3.0  4.050    Moderate
# 4       MB-0008                            8.0  6.080        High
# ...         ...                            ...    ...         ...
# 2504  MTS-T2428                            0.0  2.540         NaN
# 2505  MTS-T2429                            0.0  4.560         NaN
# 2506  MTS-T2430                            0.0    NaN         NaN
# 2507  MTS-T2431                            0.0    NaN         NaN
# 2508  MTS-T2432                            0.0    NaN         NaN
#
#      CHEMOTHERAPY  COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY  \
# 0              NO     1.0  Positve   NEUTRAL             YES
# ...

# %%
os_months = data_clinical_patient[['PATIENT_ID', 'OS_MONTHS']]
os_months_cleaned = os_months.dropna()
os_months_cleaned
# Out:
#      PATIENT_ID   OS_MONTHS
# 0       MB-0000  140.500000
# 1       MB-0002   84.633333
# 2       MB-0005  163.700000
# 3       MB-0006  164.933333
# 4       MB-0008   41.366667
# ...         ...         ...
# 1980    MB-7295  196.866667
# 1981    MB-7296   44.733333
# 1982    MB-7297  175.966667
# 1983    MB-7298   86.233333
# 1984    MB-7299  201.900000
#
# [1981 rows x 2 columns]

# %%
os_months_cleaned.describe()
# Out:
#          OS_MONTHS
# count  1981.000000
# mean    125.244271
# std      76.111772
# min       0.000000
# 25%      60.866667
# 50%     116.466667
# 75%     185.133333
# max     355.200000

# %%
methylation_promoters_rrbs_df = pd.read_csv(f'{prefix_path}/data_methylation_promoters_rrbs.txt', delimiter='\t')
methylation_promoters_rrbs_df
# Out:
#       Hugo_Symbol   MB-0006   MB-0028   MB-0035   MB-0046   MB-0050   MB-0053  \
# 0             A2M  0.045031  0.066532  0.015487  0.102439  0.001905  0.039106
# 1          A4GALT  0.017582  0.038095  0.033333  0.000000  0.009804  0.236311
# 2            AAAS  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3            AACS  0.000000  0.019802  0.000000  0.000000  0.000000  0.000000
# 4         AADACL2  0.870370  0.958763  0.987395  0.965517  0.969231  0.763359
# ...           ...       ...       ...       ...       ...       ...       ...
# 13183       ZWINT  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13184        ZXDC  0.000000  0.000000  0.000000  0.002331  0.000000  0.000000
# 13185      ZYG11B  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13186         ZYX  0.013445  0.008097  0.000000  0.000000  0.000000  0.003155
# 13187       ZZEF1  0.002770  0.004566  0.000000  0.000000  0.000000  0.003279
#
# ...

# %%
data_mrna_illumina_microarray_zscores_ref_diploid_samples = pd.read_csv(f'.{prefix_path}/data_mrna_illumina_microarray_zscores_ref_diploid_samples.txt', delimiter='\t')
data_mrna_illumina_microarray_zscores_ref_diploid_samples
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  MB-0362  MB-0346  MB-0386  MB-0574  \
# 0            RERE             473  -0.7139   1.2266  -0.0053  -0.4399
# 1          RNF165          494470  -0.4606   0.3564  -0.6800  -1.0563
# 2            PHF7           51533  -0.3325  -1.0617   0.2587  -0.2982
# 3           CIDEA            1149  -0.0129  -1.0394   3.2991  -0.2632
# 4           TENT2          167153  -0.7853   0.0337  -0.6649   2.1640
# ...           ...             ...      ...      ...      ...      ...
# 20598       VPS72            6944  -0.2908   0.3443   0.4818   0.2503
# 20599       CSMD3          114788  -0.5286  -0.4379   6.9258   1.0466
# 20600      CC2D1A           54862   0.0068  -0.7520   0.0519   0.2502
# 20601       IGSF9           57549   0.4053   1.2968   0.7962  -0.1634
# 20602      FAM71A          149647  -1.1278   0.0321   0.6608  -0.3571
#
#        MB-0185  MB-0503  MB-0641  MB-0201  ...  MB-6192  MB-4820  MB-5527  \
# ...

# %%
data_mrna_illumina_microarray = pd.read_csv(f'{prefix_path}/data_mrna_illumina_microarray.txt', delimiter='\t')
data_mrna_illumina_microarray
# Out:
#       Hugo_Symbol  Entrez_Gene_Id   MB-0362   MB-0346    MB-0386   MB-0574  \
# 0            RERE             473  8.676978  9.653589   9.033589  8.814855
# 1          RNF165          494470  6.075331  6.687887   5.910885  5.628740
# 2            PHF7           51533  5.838270  5.600876   6.030718  5.849428
# 3           CIDEA            1149  6.397503  5.246319  10.111816  6.116868
# 4           TENT2          167153  7.906217  8.267256   7.959291  9.206376
# ...           ...             ...       ...       ...        ...       ...
# 20598       VPS72            6944  8.084979  8.349115   8.406332  8.310019
# 20599       CSMD3          114788  5.161796  5.197392   8.087722  5.780062
# 20600      CC2D1A           54862  6.353215  6.132355   6.366335  6.424048
# 20601       IGSF9           57549  7.304643  7.933324   7.580336  6.903654
# 20602      FAM71A          149647  5.049591  5.316790   5.461617  5.227130
#
# ...

# %%
data_mrna_illumina_microarray_transposed = data_mrna_illumina_microarray.transpose()
data_mrna_illumina_microarray_transposed
# Out:
#                    0         1         2          3         4         5      \
# Hugo_Symbol         RERE    RNF165      PHF7      CIDEA     TENT2   SLC17A3
# Entrez_Gene_Id       473    494470     51533       1149    167153     10786
# MB-0362         8.676978  6.075331   5.83827   6.397503  7.906217  5.702379
# MB-0346         9.653589  6.687887  5.600876   5.246319  8.267256  5.521794
# MB-0386         9.033589  5.910885  6.030718  10.111816  7.959291  5.689533
# ...                  ...       ...       ...        ...       ...       ...
# MB-5453         9.606915  7.427494  5.927409   5.927031  8.520545  5.550549
# MB-5471         9.049296      6.85  6.117095   6.374305  8.499637  5.497546
# MB-5127         8.858622   6.55045  5.936371   5.963092  9.320207  5.690297
# MB-4313         8.415867  6.831722   7.40896   9.181768  6.804085  5.730308
# MB-4823         9.902776  7.338318  5.875759   5.596873  8.436732  5.788639
#
# ...

# %%
data_mrna_illumina_microarray_transposed = data_mrna_illumina_microarray.transpose()
data_mrna_illumina_microarray_transposed.drop('Entrez_Gene_Id', axis=0, inplace=True)
data_mrna_illumina_microarray_transposed
# Out:
#                 0         1         2          3         4         5      \
# Hugo_Symbol      RERE    RNF165      PHF7      CIDEA     TENT2   SLC17A3
# MB-0362      8.676978  6.075331   5.83827   6.397503  7.906217  5.702379
# MB-0346      9.653589  6.687887  5.600876   5.246319  8.267256  5.521794
# MB-0386      9.033589  5.910885  6.030718  10.111816  7.959291  5.689533
# MB-0574      8.814855   5.62874  5.849428   6.116868  9.206376   5.43913
# ...               ...       ...       ...        ...       ...       ...
# MB-5453      9.606915  7.427494  5.927409   5.927031  8.520545  5.550549
# MB-5471      9.049296      6.85  6.117095   6.374305  8.499637  5.497546
# MB-5127      8.858622   6.55045  5.936371   5.963092  9.320207  5.690297
# MB-4313      8.415867  6.831722   7.40896   9.181768  6.804085  5.730308
# MB-4823      9.902776  7.338318  5.875759   5.596873  8.436732  5.788639
#
#                 6         7         8         9      ...     20593     20594  \
# ...

# %%
data_mrna_illumina_microarray_transposed.reset_index(inplace=True)
data_mrna_illumina_microarray_transposed
# Out:
#             index         0         1         2          3         4  \
# 0     Hugo_Symbol      RERE    RNF165      PHF7      CIDEA     TENT2
# 1         MB-0362  8.676978  6.075331   5.83827   6.397503  7.906217
# 2         MB-0346  9.653589  6.687887  5.600876   5.246319  8.267256
# 3         MB-0386  9.033589  5.910885  6.030718  10.111816  7.959291
# 4         MB-0574  8.814855   5.62874  5.849428   6.116868  9.206376
# ...           ...       ...       ...       ...        ...       ...
# 1976      MB-5453  9.606915  7.427494  5.927409   5.927031  8.520545
# 1977      MB-5471  9.049296      6.85  6.117095   6.374305  8.499637
# 1978      MB-5127  8.858622   6.55045  5.936371   5.963092  9.320207
# 1979      MB-4313  8.415867  6.831722   7.40896   9.181768  6.804085
# 1980      MB-4823  9.902776  7.338318  5.875759   5.596873  8.436732
#
#              5         6         7         8  ...     20593     20594  \
# ...

# %%
data_mrna_illumina_microarray_transposed.columns = data_mrna_illumina_microarray_transposed.iloc[0]
data_mrna_illumina_microarray_transposed = data_mrna_illumina_microarray_transposed[1:].reset_index(drop=True)

# %%
data_mrna_illumina_microarray_transposed.rename(columns={'Hugo_Symbol': 'PATIENT_ID'}, inplace=True)
data_mrna_illumina_microarray_transposed
# Out:
# 0    PATIENT_ID      RERE    RNF165      PHF7      CIDEA     TENT2   SLC17A3  \
# 0       MB-0362  8.676978  6.075331   5.83827   6.397503  7.906217  5.702379
# 1       MB-0346  9.653589  6.687887  5.600876   5.246319  8.267256  5.521794
# 2       MB-0386  9.033589  5.910885  6.030718  10.111816  7.959291  5.689533
# 3       MB-0574  8.814855   5.62874  5.849428   6.116868  9.206376   5.43913
# 4       MB-0185  8.736406  6.392422  5.542133   5.184098  8.162845  5.464326
# ...         ...       ...       ...       ...        ...       ...       ...
# 1975    MB-5453  9.606915  7.427494  5.927409   5.927031  8.520545  5.550549
# 1976    MB-5471  9.049296      6.85  6.117095   6.374305  8.499637  5.497546
# 1977    MB-5127  8.858622   6.55045  5.936371   5.963092  9.320207  5.690297
# 1978    MB-4313  8.415867  6.831722   7.40896   9.181768  6.804085  5.730308
# 1979    MB-4823  9.902776  7.338318  5.875759   5.596873  8.436732  5.788639
#
# ...

# %%
result_df = pd.merge(data_mrna_illumina_microarray_transposed, os_months_cleaned, on='PATIENT_ID')
result_df.to_csv('./data/merged_mrna_dataset.csv')

# %%
result_df
# Out:
#      PATIENT_ID      RERE    RNF165      PHF7      CIDEA     TENT2   SLC17A3  \
# 0       MB-0362  8.676978  6.075331   5.83827   6.397503  7.906217  5.702379
# 1       MB-0346  9.653589  6.687887  5.600876   5.246319  8.267256  5.521794
# 2       MB-0386  9.033589  5.910885  6.030718  10.111816  7.959291  5.689533
# 3       MB-0574  8.814855   5.62874  5.849428   6.116868  9.206376   5.43913
# 4       MB-0185  8.736406  6.392422  5.542133   5.184098  8.162845  5.464326
# ...         ...       ...       ...       ...        ...       ...       ...
# 1975    MB-5453  9.606915  7.427494  5.927409   5.927031  8.520545  5.550549
# 1976    MB-5471  9.049296      6.85  6.117095   6.374305  8.499637  5.497546
# 1977    MB-5127  8.858622   6.55045  5.936371   5.963092  9.320207  5.690297
# 1978    MB-4313  8.415867  6.831722   7.40896   9.181768  6.804085  5.730308
# 1979    MB-4823  9.902776  7.338318  5.875759   5.596873  8.436732  5.788639
#
# ...

# %% [markdown]
# **Zscore MRNA**

# %%
data_mrna_illumina_microarray_zscores_ref_diploid_samples = pd.read_csv(f'.{prefix_path}/data_mrna_illumina_microarray_zscores_ref_diploid_samples.txt', delimiter='\t')
data_mrna_illumina_microarray_zscores_ref_diploid_samples
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  MB-0362  MB-0346  MB-0386  MB-0574  \
# 0            RERE             473  -0.7139   1.2266  -0.0053  -0.4399
# 1          RNF165          494470  -0.4606   0.3564  -0.6800  -1.0563
# 2            PHF7           51533  -0.3325  -1.0617   0.2587  -0.2982
# 3           CIDEA            1149  -0.0129  -1.0394   3.2991  -0.2632
# 4           TENT2          167153  -0.7853   0.0337  -0.6649   2.1640
# ...           ...             ...      ...      ...      ...      ...
# 20598       VPS72            6944  -0.2908   0.3443   0.4818   0.2503
# 20599       CSMD3          114788  -0.5286  -0.4379   6.9258   1.0466
# 20600      CC2D1A           54862   0.0068  -0.7520   0.0519   0.2502
# 20601       IGSF9           57549   0.4053   1.2968   0.7962  -0.1634
# 20602      FAM71A          149647  -1.1278   0.0321   0.6608  -0.3571
#
#        MB-0185  MB-0503  MB-0641  MB-0201  ...  MB-6192  MB-4820  MB-5527  \
# ...

# %%
data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed = data_mrna_illumina_microarray_zscores_ref_diploid_samples.transpose()
data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed
# Out:
#                  0       1       2       3       4        5       6      \
# Hugo_Symbol       RERE  RNF165    PHF7   CIDEA   TENT2  SLC17A3     SDS
# Entrez_Gene_Id     473  494470   51533    1149  167153    10786   10993
# MB-0362        -0.7139 -0.4606 -0.3325 -0.0129 -0.7853    0.763  0.8752
# MB-0346         1.2266  0.3564 -1.0617 -1.0394  0.0337  -0.5175  -0.561
# MB-0386        -0.0053   -0.68  0.2587  3.2991 -0.6649   0.6719  0.1445
# ...                ...     ...     ...     ...     ...      ...     ...
# MB-5453         1.1339  1.3429 -0.0587 -0.4324  0.6082  -0.3136 -1.1075
# MB-5471         0.0259  0.5726   0.524 -0.0336  0.5608  -0.6894 -0.1793
# MB-5127        -0.3529  0.1731 -0.0311 -0.4003  2.4222   0.6773   1.511
# MB-4313        -1.2327  0.5482  4.4925  2.4698 -3.2853    0.961  2.1707
# MB-4823         1.7217  1.2239 -0.2173 -0.7268  0.4181   1.3746 -0.8606
#
#                    7       8       9      ...     20593   20594   20595  \
# ...

# %%
data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed.drop('Entrez_Gene_Id', axis=0, inplace=True)
data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed.reset_index(inplace=True)

data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed.columns = data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed.iloc[0]
data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed = data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed[1:].reset_index(drop=True)

data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed.rename(columns={'Hugo_Symbol': 'PATIENT_ID'}, inplace=True)

result_zscore_df = pd.merge(data_mrna_illumina_microarray_zscores_ref_diploid_samples_transposed, os_months_cleaned, on='PATIENT_ID')

result_zscore_df.to_csv('./data/merged_mrna_zscore_dataset.csv')

# %%
result_zscore_df
# Out:
#      PATIENT_ID    RERE  RNF165    PHF7   CIDEA   TENT2 SLC17A3     SDS  \
# 0       MB-0362 -0.7139 -0.4606 -0.3325 -0.0129 -0.7853   0.763  0.8752
# 1       MB-0346  1.2266  0.3564 -1.0617 -1.0394  0.0337 -0.5175  -0.561
# 2       MB-0386 -0.0053   -0.68  0.2587  3.2991 -0.6649  0.6719  0.1445
# 3       MB-0574 -0.4399 -1.0563 -0.2982 -0.2632   2.164 -1.1036 -0.0361
# 4       MB-0185 -0.5958 -0.0377 -1.2422 -1.0949 -0.2031  -0.925  -0.627
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1975    MB-5453  1.1339  1.3429 -0.0587 -0.4324  0.6082 -0.3136 -1.1075
# 1976    MB-5471  0.0259  0.5726   0.524 -0.0336  0.5608 -0.6894 -0.1793
# 1977    MB-5127 -0.3529  0.1731 -0.0311 -0.4003  2.4222  0.6773   1.511
# 1978    MB-4313 -1.2327  0.5482  4.4925  2.4698 -3.2853   0.961  2.1707
# 1979    MB-4823  1.7217  1.2239 -0.2173 -0.7268  0.4181  1.3746 -0.8606
#
#      ATP6V1C2      F3  ...   VN1R4   TRPV5   UGGT1 CR590356   VPS72   CSMD3  \
# ...
